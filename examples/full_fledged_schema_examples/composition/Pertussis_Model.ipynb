# %%
using GraphViz

using StockFlow
using StockFlow.Syntax

using Catlab
using Catlab.CategoricalAlgebra
using LabelledArrays
using OrdinaryDiffEq
using Plots

using Catlab.Graphics
using Catlab.Programs
using Catlab.Theories
using Catlab.WiringDiagrams

# %% [markdown]
# ![pertussis_model.png](figures/pertussis_model.png)
#
# cite from paper: Hethcote, Herbert W. "An age-structured model for pertussis transmission." Mathematical biosciences 145.2 (1997): 89-136.

# %%
++(s1, s2) = Symbol(string(s1) * string(s2))
# Out:
# ++ (generic function with 1 method)

# %% [markdown]
# # 1. Define the components of all the sub-models
# ## 1.1 Define open sub-model including each stock and its death flow

# %%
function fOpenDeaths(s)
    s_Stock = Symbol(s)
    Deaths_s = "Deaths_" ++ s
    v_Deaths_s = "v_Deaths_s" ++ s
    rDeath = :rDeath
    
    Open(
        StockAndFlowF(
            # stocks
            (
                s_Stock => (:F_NONE, Deaths_s, :N)
            ),
            # parameters
            (
                rDeath
            ),
            # dynamic variables
            (
                v_Deaths_s => ((s_Stock, rDeath) => :*)
            ),
            # flows
            (
                Deaths_s => v_Deaths_s
            ),
            # sums
            (
                :N
            )
        ),
        # feet
        foot(Symbol(s),:N,Symbol(s)=>:N)
        
    )
end
# Out:
# fOpenDeaths (generic function with 1 method)

# %% [markdown]
# ### For example, the deaths sub-model of stock "S" is:

# %%
Graph(apex(fOpenDeaths("S")))
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "S", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("fs_1d", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "", :shape => "point", :color => "white")), Catlab.Graphics.Graphviz.Node("v1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_Deaths_sS", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("sv1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "N", :shape => "circle", :color => "black", :fillcolor => "cornflowerblue", :style => "filled")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "", :labelfontsize => "6", :color => "black:invis:black", :arrowhead => "none", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("v1", "", ""), Catlab.Graphics.Graphviz.NodeID("fs_1d", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Deaths_S", :labelfontsize => "6", :color => "black:invis:black", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:splines => "splines"))

# %% [markdown]
# ## 1.2 Define the SIR sub-model including the flow of new borns to stock S

# %%
openSIR = Open(
    (@stock_and_flow begin
        :stocks
        S
        I
        R4

        :parameters
        γ
        rBirth
        β

        :flows
        CLOUD => births(N * rBirth) => S
        S => infs(S * β * NI / N) => I
        I => recI(I * γ) => R4

        :sums
        N = [S, I, R4]
        NI = [I]



    end),
        # feet
        foot(:S,:N,:S=>:N),
        foot(:I,:N,:I=>:N),
        foot(:R4,:N,:R4=>:N),
        foot((),:NI,())

)
Graph(apex(openSIR))
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "S", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "I", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R4", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("fs_1u", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "", :shape => "point", :color => "white")), Catlab.Graphics.Graphviz.Node("v1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "##v_births#292", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "##v_infs#293", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "##v_infs#294", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "##v_infs#295", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "##v_recI#296", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("sv1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "N", :shape => "circle", :color => "black", :fillcolor => "cornflowerblue", :style => "filled"))  …  Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("v1", "", ""), Catlab.Graphics.Graphviz.NodeID("s1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "births", :labelfontsize => "6", :color => "black:invis:black", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("v5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("sv2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s3", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catla ...

# %% [markdown]
# ## 1.3 Define the open sub-model of VRIR, including V1R1ImR4 and V2R2IwR4

# %%
# n: string of "1" or "2"
# mw:string of "m" or "w"
function openVRIR(n, mw)
    Vn = "V" ++ n
    infVn = "infV" ++ n
    v_infVn₁ = ("v_infV" ++ n) ++ raw"\_1"
    v_infVn₂ = ("v_infV" ++ n) ++ raw"\_2"
    v_infVn₃ = ("v_infV" ++ n) ++ raw"\_3"


    
    Rn = "R" ++ n
    infRn = "infR" ++ n
    v_infRn₁ = ("v_infR" ++ n) ++ raw"\_1"
    v_infRn₂ = ("v_infR" ++ n) ++ raw"\_2"
    v_infRn₃ = ("v_infR" ++ n) ++ raw"\_3"



    Imw = "I" ++ mw
    recImw = "recI" ++ mw
    v_recImw = "v_recI" ++ mw

    R4 = :R4
    β = :β
    γ = :γ

    Open(
        StockAndFlowF(
            #stocks
            (
                Vn => (:F_NONE, infVn, :N),
                Rn => (:F_NONE, infRn, :N),
                Imw => ((infVn, infRn), recImw, (:N, :NI)),
                R4 => (recImw, :F_NONE, :N)
            ),

            # parameters
            (
                β,
                γ
            ),

            # dynamic variables
            (
                v_infVn₁ => ((Vn, β) => :*),
                v_infVn₂ => ((v_infVn₁, :NI) => :*),
                v_infVn₃ => ((v_infVn₂, :N) => :/),

                v_infRn₁ => ((Rn, β) => :*),
                v_infRn₂ => ((v_infRn₁, :NI) => :*),
                v_infRn₃ => ((v_infRn₂, :N) => :/),

                v_recImw => ((Imw, γ) => :*)
            ),

            # flows
            (
                infVn => v_infVn₃,
                infRn => v_infRn₃,
                recImw => v_recImw
            ),

            # sums
            (
                :N,
                :NI
            )


        ),
        # feet
        foot(Vn, :N, Vn=>:N),
        foot(Imw, :N, Imw=>:N),
        foot(Rn, :N, Rn=>:N),
        foot(R4,:N,R4=>:N),
        foot((),:NI,())
    
    )

end
# Out:
# openVRIR (generic function with 1 method)

# %% [markdown]
# ### For example, the V1R1ImR4 model is:

# %%
Graph(apex(openVRIR("1","m")))
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "V1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Im", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R4", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("v1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infV1\\_1", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infV1\\_2", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infV1\\_3", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infR1\\_1", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infR1\\_2", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infR1\\_3", :shape => "plaintext", :fontcolor => "black"))  …  Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s3", "", ""), Catlab.Graphics.Graphviz.NodeID("sv2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s3", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s4", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv1", "", ""), Catlab.Graphics.Graphviz.NodeID("v6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv2", "", ""), Catlab.Graphics.Graphviz.NodeID("v5", "", "" ...

# %% [markdown]
# ## 1.4 Define the immunity increase and decrease between two levels of V or R

# %%
function fOpenImmunity(us, ds, r)

    us_Stock = Symbol(us)
    ds_Stock = Symbol(ds)
    r_Param = Symbol(r) # r was already a symbol, so this doesn't matter
    

    dsWaningImmunity = ds ++ "WaningImmunity"
    Vaccus = "Vacc" ++ us
    v_Vaccus = "v_Vacc" ++ us

    v_WanImmuds = "v_WanImmu" ++ ds

    vacc = :vacc


    Open(
        StockAndFlowF(
            # stocks
            (
                us_Stock => (dsWaningImmunity, Vaccus, :N),
                ds_Stock => (Vaccus, dsWaningImmunity, :N)
            ),
            # parameters
            (
                vacc,
                r_Param
            ),
            # dynamic variables
            (
                v_WanImmuds => ((ds_Stock, r_Param) => :*),
                v_Vaccus => ((us_Stock, vacc) => :*)
            ),
            # flows
            (
                dsWaningImmunity => v_WanImmuds,
                Vaccus => v_Vaccus
            ),
            # sums
            (
                :N
            )

        ),

            # feet
            foot(Symbol(us),:N,Symbol(us)=>:N),
            foot(Symbol(ds),:N,Symbol(ds)=>:N)

    )


end
# Out:
# fOpenImmunity (generic function with 1 method)

# %% [markdown]
# ### For example, the sub-model between R1 and R2 is:

# %%
Graph(apex(fOpenImmunity("R1","R2",:α)))
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R2", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("v1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_WanImmuR2", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_VaccR1", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("sv1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "N", :shape => "circle", :color => "black", :fillcolor => "cornflowerblue", :style => "filled")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "", :labelfontsize => "6", :color => "black:invis:black", :arrowhead => "none", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("v1", "", ""), Catlab.Graphics.Graphviz.NodeID("s1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R2WaningImmunity", :labelfontsize => "6", :color => "black:invis:black", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "", :labelfontsize => "6", :color => "black:invis:black", :arrowhead => "none", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("v2", "", ""), Catlab.Graphics.Graphviz.NodeID("s2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "VaccR1", :labelfontsize => "6", :color => "black:invis:black", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:splines => "splines"))

# %% [markdown]
# ## 1.5 The rest sub-model components
# ### 1.5.1 The rest sub-model components of new infectious
# Including, the new infectious from stock R3 or V3 to R4

# %%
function fOpenR3OrV3ToR4(s)
    s_Stock = Symbol(s)
    
    infs = "inf" ++ s
    v_infs₁ = ("v_inf" ++ s) ++ raw"\_1"
    v_infs₂ = ("v_inf" ++ s) ++ raw"\_2"
    v_infs₃ = ("v_inf" ++ s) ++ raw"\_3"

    R4 = :R4
    β = :β

    Open(
        StockAndFlowF(
            # stocks
            (
                s_Stock => (:F_NONE, infs, :N),
                R4 => (infs, :F_NONE, :N)
            ),
            # parameters
            (
                β
            ),
            # dynamic variables
            (
                v_infs₁ => ((s_Stock, β) => :*),
                v_infs₂ => ((v_infs₁, :NI) => :*),
                v_infs₃ => ((v_infs₂, :N) => :/)
            ),
            # flows
            (
                infs => v_infs₃
            ),
            # sums
            (
                :N,
                :NI
            )
        ),
   # feet
   foot(Symbol(s),:N,Symbol(s)=>:N),
   foot(:R4,:N,:R4=>:N),
   foot((),:NI,())

    )



end
# Out:
# fOpenR3OrV3ToR4 (generic function with 1 method)

# %% [markdown]
# ### For example, sub-model of new infectious from Stock V3 to R4

# %%
Graph(apex(fOpenR3OrV3ToR4("V3")))
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "V3", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R4", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("v1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infV3\\_1", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infV3\\_2", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("v3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "v_infV3\\_3", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("sv1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "N", :shape => "circle", :color => "black", :fillcolor => "cornflowerblue", :style => "filled")), Catlab.Graphics.Graphviz.Node("sv2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "NI", :shape => "circle", :color => "black", :fillcolor => "cornflowerblue", :style => "filled")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "", :labelfontsize => "6", :color => "black:invis:black", :arrowhead => "none", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("v3", "", ""), Catlab.Graphics.Graphviz.NodeID("s2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "infV3", :labelfontsize => "6", :color => "black:invis:black", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv1", "", ""), Catlab.Graphics.Graphviz.NodeID("v3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv2", "", ""), Catlab.Graphics.Graphviz.NodeID("v2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:splines => "splines"))

# %% [markdown]
# ### 1.5.2 The rest sub-model components of waning immunity from Stock R1 to S

# %%
OpenR1ToS = Open(
    (@stock_and_flow begin
        :stocks
        R1
        S

        :parameters
        ϵ

        :flows
        R1 => fWaningImmunityR1(R1 * ϵ) => S

        :sums
        N = [R1, S]
    end),

    foot(:R1,:N,:R1=>:N),
    foot(:S,:N,:S=>:N)


)
# Out:
# StructuredCospan{Catlab.CategoricalAlgebra.StructuredCospans.DiscreteACSet{StockAndFlow0, StockAndFlowF}, Multicospan{StockAndFlowF, StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV}, Tuple{(:lss, :LS, :S), (:lssv, :LS, :SV), (:ifn, :I, :F), (:is, :I, :S), (:ofn, :O, :F), (:os, :O, :S), (:fv, :F, :V), (:lvs, :LV, :S), (:lvv, :LV, :V), (:lsvsv, :LSV, :SV), (:lsvv, :LSV, :V), (:lvsrc, :LVV, :V), (:lvtgt, :LVV, :V), (:lpvp, :LPV, :P), (:lpvv, :LPV, :V)}, Tuple{:Name, :Op, :Position}, Tuple{(:sname, :S, :Name), (:svname, :SV, :Name), (:fname, :F, :Name), (:vname, :V, :Name), (:pname, :P, :Name), (:vop, :V, :Op), (:lvsposition, :LV, :Position), (:lsvsvposition, :LSV, :Position), (:lvsrcposition, :LVV, :Position), (:lpvpposition, :LPV, :Position)}}, NamedTuple{(:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV), Tuple{Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Vararg{Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, UnitRange{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, 9}}}, StockAndFlowF, StockAndFlowF}, StaticArraysCore.SVector{2, StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV}, Tuple{(:lss, :LS, :S), (:lssv, :LS, :SV), (:ifn, :I, :F), (:is, :I, :S), (:ofn, :O, :F), (:os, :O, :S), (:fv, :F, :V), (:lvs, :LV, :S), (:lvv, :LV, :V), (:lsvsv, :LSV, :SV), (:lsvv, :LSV, :V), (:lvsrc, :LVV, :V), (:lvtgt, :LVV, :V), (:lpvp, :LPV, :P), (:lpvv, :LPV, :V)}, Tuple{:Name, :Op, :Position}, Tuple{(:sname, :S, :Name), (:svname, :SV, :Name), (:fname, :F, :Name), (:vname, :V, :Name), (:pname, :P, :Name), (:vop, :V, :Op), (:lvsposition, :LV, :Position), (:lsvsvposition, :LSV, :Position), (:lvsrcposition, :LVV, :Position), (:lpvpposition, :LPV, :Position)}}, NamedTuple{(:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV), Tuple{Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Vararg{Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, UnitRange{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, 9}}}, StockAndFlowF, StockAndFlowF}}}, StaticArraysCore.SVector{2, StockAndFlow0}}(Multicospan{StockAndFlowF, StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV}, Tuple{(:lss, :LS, :S), (:lssv, :LS, :SV), (:ifn, :I, :F), (:is, :I, :S), (:ofn, :O, :F), (:os, :O, :S), (:fv, :F, :V), (:lvs, :LV, :S), (:lvv, :LV, :V), (:lsvsv, :LSV, :SV), (:lsvv, :LSV, :V), (:lvsrc, :LVV, :V), (:lvtgt, :LVV, :V), (:lpvp, :LPV, :P), (:lpvv, :LPV, :V)}, Tuple{:Name, :Op, :Position}, Tuple{(:sname, :S, :Name), (:svname, :SV, :Name), (:fname, :F, :Name), (:vname, :V, :Name), (:pname, :P, :Name), (:vop, :V, :Op), (:lvsposition, :LV, :Position), (:lsvsvposition, :LSV, :Position), (:lvsrcposition, :LVV, :Position), (:lpvpposition, :LPV, :Position)}}, NamedTuple{(:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV), Tuple{Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Vararg{Ca ...
#   S = 1:2
#   SV = 1:1
#   LS = 1:2
#   F = 1:1
#   I = 1:1
#   O = 1:1
#   V = 1:1
#   LV = 1:1
#   LSV = 1:0
#   P = 1:1
#   LVV = 1:0
#   LPV = 1:1
#   lss : LS → S = [1, 2]
#   lssv : LS → SV = [1, 1]
#   ifn : I → F = [1]
#   is : I → S = [2]
#   ofn : O → F = [1]
#   os : O → S = [1]
#   fv : F → V = [1]
#   lvs : LV → S = [1]
#   lvv : LV → V = [1]
#   lsvsv : LSV → SV = Int64[]
#   lsvv : LSV → V = Int64[]
#   lvsrc : LVV → V = Int64[]
#   lvtgt : LVV → V = Int64[]
#   lpvp : LPV → P = [1]
#   lpvv : LPV → V = [1]
#   sname : S → Name = [:R1, :S]
#   svname : SV → Name = [:N]
#   fname : F → Name = [:fWaningImmunityR1]
#   vname : V → Name = [Symbol("##v_fWaningImmunityR1#297")]
#   pname : P → Name = [:ϵ]
#   vop : V → Op = [:*]
#   lvsposition : LV → Position = Int8[1]
#   lsvsvposition : LSV → Position = Int8[]
#   lvsrcposition : LVV → Position = Int8[]
#   lpvpposition : LPV → Position = Int8[2], StructTightACSetTransformation{TypeLevelBasicSchema{Symbol, Tuple{:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV}, Tuple{(:lss, :LS, :S), (:lssv, :LS, :SV), (:ifn, :I, :F), (:is, :I, :S), (:ofn, :O, :F), (:os, :O, :S), (:fv, :F, :V), (:lvs, :LV, :S), (:lvv, :LV, :V), (:lsvsv, :LSV, :SV), (:lsvv, :LSV, :V), (:lvsrc, :LVV, :V), (:lvtgt, :LVV, :V), (:lpvp, :LPV, :P), (:lpvv, :LPV, :V)}, Tuple{:Name, :Op, :Position}, Tuple{(:sname, :S, :Name), (:svname, :SV, :Name), (:fname, :F, :Name), (:vname, :V, :Name), (:pname, :P, :Name), (:vop, :V, :Op), (:lvsposition, :LV, :Position), (:lsvsvposition, :LSV, :Position), (:lvsrcposition, :LVV, :Position), (:lpvpposition, :LPV, :Position)}}, NamedTuple{(:S, :SV, :LS, :F, :I, :O, :V, :LV, :LSV, :P, :LVV, :LPV), Tuple{Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, Vector{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, Vararg{Catlab.CategoricalAlgebra.FinSets.FinDomFunctionVector{Int64, UnitRange{Int64}, Catlab.CategoricalAlgebra.FinSets.FinSetInt}, 9}}}, StockAndFlowF, StockAndFlowF}[ACSetTransformation((S = FinFunction([1], 1, 2), SV = FinFunction([1], 1, 1), LS = FinFunction([1], 1, 2), F = FinFunction(1:0, 0, 1), I = FinFunction(1:0, 0, 1), O = FinFunction(1:0, 0, 1), V = FinFunction(1:0, 0, 1), LV = FinFunction(1:0, 0, 1), LSV = FinFunction(1:0, 0, 0), P = FinFunction(1:0, 0, 1), LVV = FinFunction(1:0, 0, 0), LPV = FinFunction(1:0, 0, 1)), StockAndFlowF {S = 1, SV = 1, LS = 1, F = 0, I = 0, O = 0, V = 0, LV = 0, LSV = 0, P = 0, LVV = 0, LPV = 0}, StockAndFlowF {S = 2, SV = 1, LS = 2, F = 1, I = 1, O = 1, V = 1, LV = 1, LSV = 0, P = 1, LVV = 0, LPV = 1}), ACSetTransformation((S = FinFunction([2], 1, 2), SV = FinFunction([1], 1, 1), LS = FinFunction([2], 1, 2), F = FinFunction(1:0, 0, 1), I = FinFunction(1:0, 0, 1), O = FinFunction(1:0, 0, 1), V = FinFunction(1:0, 0, 1), LV = FinFunction(1:0, 0, 1), LSV = FinFunction(1:0, 0, 0), P = FinFunction(1:0, 0, 1), LVV = FinFunction(1:0, 0, 0), LPV = FinFunction(1:0, 0, 1)), StockAndFlowF {S = 1, SV = 1, LS = 1, F = 0, I = 0, O = 0, V = 0, LV = 0, LSV = 0, P = 0, LVV = 0, LPV = 0}, StockAndFlowF {S = 2, SV = 1, LS = 2, F = 1, I = 1, O = 1, V = 1, LV = 1, LSV = 0, P = 1, LVV = 0, LPV = 1})]), StockAndFlow0[StockAndFlow0:
#   S = 1:1
#   SV = 1:1
#   LS = 1:1
#   lss : LS → S = [1]
#   lssv : LS → SV = [1]
#   sname : S → Name = [:R1]
#   svname : SV → Name = [:N], StockAndFlow0:
#   S = 1:1
#   SV = 1:1
#   LS = 1:1
#   lss : LS → S = [1]
#   lssv : LS → SV = [1]
#   sname : S → Name = [:S]
#   svname : SV → Name = [:N]])

# %%
Graph(apex(OpenR1ToS))
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "S", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("v1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "##v_fWaningImmunityR1#297", :shape => "plaintext", :fontcolor => "black")), Catlab.Graphics.Graphviz.Node("sv1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "N", :shape => "circle", :color => "black", :fillcolor => "cornflowerblue", :style => "filled")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "", :labelfontsize => "6", :color => "black:invis:black", :arrowhead => "none", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("v1", "", ""), Catlab.Graphics.Graphviz.NodeID("s2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "fWaningImmunityR1", :labelfontsize => "6", :color => "black:invis:black", :splines => "ortho")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("v1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s1", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s2", "", ""), Catlab.Graphics.Graphviz.NodeID("sv1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:splines => "splines"))

# %% [markdown]
# # 2. Composition

# %%
# define the UWD-algebra of Hyperglycemic Model
pertussis_uwd = @relation (S,I,Im,Iw,R1,R2,R3,R4,V1,V2,V3,V4,NI) begin
    SD(S)
    ID(I)
    ImD(Im)
    IwD(Iw)
    R1D(R1)
    R2D(R2)
    R3D(R3)
    R4D(R4)
    V1D(V1)
    V2D(V2)
    V3D(V3)
    V4D(V4)
    SIR4(S,I,R4,NI)
    V1R1ImR4(V1,Im,R1,R4,NI)
    V2R2IwR4(V2,Iw,R2,R4,NI)
    R1R2(R1,R2)
    R2R3(R2,R3)
    R3R4(R3,R4)
    SV1(S,V1)
    V1V2(V1,V2)
    V2V3(V2,V3)
    V3V4(V3,V4)
    V3R4I(V3,R4,NI)
    R3R4I(R3,R4,NI)
    R1S(R1,S)
end;
display_uwd(pertussis_uwd)
# Out:
# Graph("G", false, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box1", :label => "SD")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box2", :label => "ID")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box3", :label => "ImD")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box4", :label => "IwD")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box5", :label => "R1D")), Catlab.Graphics.Graphviz.Node("n6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box6", :label => "R2D")), Catlab.Graphics.Graphviz.Node("n7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box7", :label => "R3D")), Catlab.Graphics.Graphviz.Node("n8", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box8", :label => "R4D")), Catlab.Graphics.Graphviz.Node("n9", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box9", :label => "V1D")), Catlab.Graphics.Graphviz.Node("n10", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:id => "box10", :label => "V2D"))  …  Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n36", "", ""), Catlab.Graphics.Graphviz.NodeID("n49", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n12", "", ""), Catlab.Graphics.Graphviz.NodeID("n50", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n22", "", ""), Catlab.Graphics.Graphviz.NodeID("n50", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n37", "", ""), Catlab.Graphics.Graphviz.NodeID("n50", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n13", "", ""), Catlab.Graphics.Graphviz.NodeID("n51", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n14", "", ""), Catlab.Graphics.Graphviz.NodeID("n51", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n15", "", ""), Catlab.Graphics.Graphviz.NodeID("n51", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n23", "", ""), Catlab.Graphics.Graphviz.NodeID("n51", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n24", "", ""), Catlab.Graphics.Graphviz.NodeID("n51", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n38", "", ""), Catlab.Graphics.Graphviz.NodeID("n51", "",  ...

# %%
pertussis_model = oapply(pertussis_uwd,Dict(
    :SD=>fOpenDeaths("S"),
    :ID=>fOpenDeaths("I"),
    :ImD=>fOpenDeaths("Im"),
    :IwD=>fOpenDeaths("Iw"),
    :V1D=>fOpenDeaths("V1"),
    :V2D=>fOpenDeaths("V2"),
    :V3D=>fOpenDeaths("V3"),
    :V4D=>fOpenDeaths("V4"),
    :R1D=>fOpenDeaths("R1"),
    :R2D=>fOpenDeaths("R2"),
    :R3D=>fOpenDeaths("R3"),
    :R4D=>fOpenDeaths("R4"),
    :SIR4=>openSIR,
    :V1R1ImR4=>openVRIR("1","m"),
    :V2R2IwR4=>openVRIR("2","w"),
    :R1R2=>fOpenImmunity("R1","R2",:α),
    :R2R3=>fOpenImmunity("R2","R3",:α),
    :R3R4=>fOpenImmunity("R3","R4",:α),
    :SV1=>fOpenImmunity("S","V1",:ϵ),
    :V1V2=>fOpenImmunity("V1","V2",:τ),
    :V2V3=>fOpenImmunity("V2","V3",:τ),
    :V3V4=>fOpenImmunity("V3","V4",:τ),
    :R3R4I=>fOpenR3OrV3ToR4("R3"),
    :V3R4I=>fOpenR3OrV3ToR4("V3"),
    :R1S=>OpenR1ToS
    )) |> apex
Graph(pertussis_model)
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "S", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "I", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Im", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Iw", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R2", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R3", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s8", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R4", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s9", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "V1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s10", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "V2", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB"))  …  Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv2", "", ""), Catlab.Graphics.Graphviz.NodeID("v29", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv1", "", ""), Catlab.Graphics.Graphviz.NodeID("v27", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv2", "", ""), Catlab.Graphics.Graphviz.NodeID("v26", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv1", "", ""), Catlab.Graphics.Graphviz.NodeID("v23", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv2", "", ""), Catlab.Graphics.Graphviz.NodeID("v22", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv1", "", ""), Catlab.Graphics.Graphviz.NodeID("v20", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("sv2", "", ""), Catlab.Graphics.Graphviz.NodeID("v19", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Gr ...

# %%
Graph(pertussis_model,type="SF")
# Out:
# Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("s1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "S", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "I", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Im", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Iw", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R2", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R3", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s8", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "R4", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s9", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "V1", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB")), Catlab.Graphics.Graphviz.Node("s10", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "V2", :shape => "square", :color => "black", :style => "filled", :fillcolor => "#9ACEEB"))  …  Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s3", "", ""), Catlab.Graphics.Graphviz.NodeID("fs_3d", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Deaths_Im", :labelfontsize => "6", :color => "black:invis:black")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s4", "", ""), Catlab.Graphics.Graphviz.NodeID("fs_4d", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Deaths_Iw", :labelfontsize => "6", :color => "black:invis:black")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s5", "", ""), Catlab.Graphics.Graphviz.NodeID("fs_5d", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Deaths_R1", :labelfontsize => "6", :color => "black:invis:black")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s6", "", ""), Catlab.Graphics.Graphviz.NodeID("fs_6d", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Deaths_R2", :labelfontsize => "6", :color => "black:invis:black")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("s7", "", ""), Catlab.Graphics.Graphviz.NodeID("fs_7d", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "Deaths_R3", :labelfontsize => "6", :color => "black:invis:black")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.No ...

# %% [markdown]
# # Solve ODEs

# %%
# define values of constant parameters
p = LVector(
    β=0.184, rBirth=30*0.32/365.0, rDeath=30*0.32/365.0, ϵ=30.0 * 0.01 / 365.0, 
    vacc=1.0/4.0, α=30.0 * 1.0 / (5 * 365), τ=30.0 * 1.0 / (2 * 365), γ=30.0 * 1.0 / 21
)
# define initial values for stocks
u0 = LVector(
    S=863544.0, I=10.0, Im=0.0, Iw=0.0,
    R1=0.0, R2=0.0, R3=0.0, R4=0.0,
    V1=0.0, V2=0.0, V3=0.0, V4=0.0
)
# Out:
# 12-element LArray{Float64, 1, Vector{Float64}, (:S, :I, :Im, :Iw, :R1, :R2, :R3, :R4, :V1, :V2, :V3, :V4)}:
#   :S => 863544.0
#   :I => 10.0
#  :Im => 0.0
#  :Iw => 0.0
#  :R1 => 0.0
#  :R2 => 0.0
#  :R3 => 0.0
#  :R4 => 0.0
#  :V1 => 0.0
#  :V2 => 0.0
#  :V3 => 0.0
#  :V4 => 0.0

# %%
# results are tested the same as the Anylogic model
prob_pertussis = ODEProblem(vectorfield(pertussis_model),u0,(0.0,24.0),p);
sol = solve(prob_pertussis,Tsit5(),abstol=1e-8);
plot(sol)

# %%
# to have the figures plotted fix to the wider of the cells
HTML("""
<style>
.output_svg div{
  width: 100% !important;
  height: 100% !important;
}
</style>
""")
# Out:
# HTML{String}("<style>\n.output_svg div{\n  width: 100% !important;\n  height: 100% !important;\n}\n</style>\n")
